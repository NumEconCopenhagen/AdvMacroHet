# %% [markdown]
# # HANC with government and no capital

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Setup](#toc1_)
# - 2. [Exercises](#toc2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({"axes.grid" : True, "grid.color": "black", "grid.alpha":"0.25", "grid.linestyle": "--"})
plt.rcParams.update({'font.size': 14})

from HANCGovModel import HANCGovModelClass

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Setup](#toc0_)

# %%
model = HANCGovModelClass(name='baseline')

# %%
par = model.par
ss = model.ss

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Exercises](#toc0_)

# %% [markdown]
# **Question 1:** Define the stationary equilibrium.

# %% [markdown]
# **Question 2:** Solve and simulate the household problem with $p^{B}_{ss}=0.975$ and $\tau_{ss}=0.12$. Set `ss.pB` and `ss.tau`, then use `model.solve_hh_ss()` and `model.simulate_hh_ss()`.

# %% [markdown]
# **Question 3:** Find the stationary equilibrium with $G_{ss}=0.10$ and $\tau_{ss}=0.12$, using `model.find_ss(tau=0.12)`. Look at `obj_ss` and `find_ss` in `steady_state.py`: what is the unknown, and what is the target? Check that the goods market clears.

# %% [markdown]
# **Question 4:** What happens for $\tau_{ss}\in(0.11,0.15)$? Plot $p^{B}_{ss}$ and $B_{ss}$ against $\tau_{ss}$.

# %% [markdown]
# **Question 5:** When is average household utility, `ss.U_hh`, maximized?
